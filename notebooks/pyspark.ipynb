# %%
import pyspark

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("sample").getOrCreate()

# Read sample data
df = spark.createDataFrame([
    (1, "Alice", 25),
    (2, "Bob", 30),
    (3, "Charlie", 35)
], ["id", "name", "age"])

df.show()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/06 17:27:04 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# +---+-------+---+
# | id|   name|age|
# +---+-------+---+
# |  1|  Alice| 25|
# |  2|    Bob| 30|
# |  3|Charlie| 35|
# +---+-------+---+
